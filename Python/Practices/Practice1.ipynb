# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', parse_dates=['dob'])

# %%
df.sample(10)
# Out:
#                     id  gender        dob  zipcode employment_status  \
# 1845         Evan Cook    male 1949-09-30    89127           retired
# 188   Jackson Anderson    male 1965-06-14    43210          employed
# 1263   Jackson Schmidt    male 1956-08-30    89136          employed
# 1268      Steven Brown    male 1944-09-04    94110           retired
# 1516      Justin Bauer    male 1944-07-30    10001           retired
# 852        Adam Parker    male 1941-07-07    94105           retired
# 42     Jessica Daniels  female 1957-06-22    44101          employed
# 1356    Allison Harper  female 1947-01-28    89136           retired
# 873      Oliver George    male 1950-09-11    10001           retired
# 380         Jude Stone    male 1951-12-03    94105           retired
#
#       education marital_status  children  ancestry  avg_commute  \
# 1845  bachelors        married         0   Hungary        39.75
# 188   bachelors         single         2  Portugal        36.58
# ...

# %%
df.describe()
# Out:
#             zipcode     children  avg_commute  daily_internet_use  \
# count   2000.000000  2000.000000  2000.000000         2000.000000
# mean   63387.827500     2.266500    30.376895            4.993325
# std    30165.490876     1.615792    10.026961            1.387846
# min    10001.000000     0.000000    -2.470000            1.010000
# 25%    43221.000000     1.000000    23.460000            4.020000
# 50%    60612.000000     2.000000    30.320000            5.010000
# 75%    90008.000000     3.000000    37.127500            5.972500
# max    94110.000000     7.000000    63.730000            8.820000
#
#        available_vehicles
# count         2000.000000
# mean             1.746000
# std              1.118977
# min              0.000000
# 25%              1.000000
# 50%              2.000000
# 75%              3.000000
# max              4.000000

# %%
df.sample(5)
# Out:
#                     id  gender        dob  zipcode employment_status  \
# 1798     Eleanor Hogan  female 1932-06-22    60612           retired
# 1206   Savannah Harmon  female 1957-05-30    89127          employed
# 487      Isabella Diaz  female 1966-09-14    43221          employed
# 573   Brooklyn Johnson  female 1969-09-16    90015          employed
# 580         Noah Scott    male 1972-08-15    90008          employed
#
#       education marital_status  children ancestry  avg_commute  \
# 1798  bachelors         single         6  England        47.83
# 1206    masters        married         5  Belgium        18.21
# 487   bachelors         single         2   France        23.34
# 573   bachelors         single         2   Poland        47.07
# 580      phd/md        married         1  Ireland        24.79
#
#       daily_internet_use  available_vehicles military_service  \
# 1798                5.46                   2               no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  2000 non-null   object
#  1   gender              2000 non-null   object
#  2   dob                 2000 non-null   datetime64[ns]
#  3   zipcode             2000 non-null   int64
#  4   employment_status   2000 non-null   object
#  5   education           2000 non-null   object
#  6   marital_status      2000 non-null   object
#  7   children            2000 non-null   int64
#  8   ancestry            2000 non-null   object
#  9   avg_commute         2000 non-null   float64
#  10  daily_internet_use  2000 non-null   float64
#  11  available_vehicles  2000 non-null   int64
#  12  military_service    2000 non-null   object
#  13  disease             2000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(8)
# ...

# %%
df.convert_dtypes().dtypes
# Out:
# id                            string
# gender                        string
# dob                   datetime64[ns]
# zipcode                        Int64
# employment_status             string
# education                     string
# marital_status                string
# children                       Int64
# ancestry                      string
# avg_commute                  float64
# daily_internet_use           float64
# available_vehicles             Int64
# military_service              string
# disease                       string
# dtype: object

# %%
#cambiar la etiqueta 'id' por nombre

# %%
df.nunique()
# Out:
# id                    2000
# gender                   2
# dob                   1877
# zipcode                 13
# employment_status        4
# education                6
# marital_status           2
# children                 8
# ancestry                20
# avg_commute           1523
# daily_internet_use     574
# available_vehicles       5
# military_service         2
# disease                 13
# dtype: int64

# %%
df[['gender', 'employment_status', 'marital_status','military_service']] = df[['gender', 'employment_status', 'marital_status','military_service']].astype('category')

# %%
df.nunique()
# Out:
# id                    2000
# gender                   2
# dob                   1877
# zipcode                 13
# employment_status        4
# education                6
# marital_status           2
# children                 8
# ancestry                20
# avg_commute           1523
# daily_internet_use     574
# available_vehicles       5
# military_service         2
# disease                 13
# dtype: int64

# %%
df.dtypes
# Out:
# id                            object
# gender                      category
# dob                   datetime64[ns]
# zipcode                        int64
# employment_status           category
# education                     object
# marital_status              category
# children                       int64
# ancestry                      object
# avg_commute                  float64
# daily_internet_use           float64
# available_vehicles             int64
# military_service            category
# disease                       object
# dtype: object

# %%
df[['dob']]
# Out:
#             dob
# 0    1944-03-09
# 1    1966-07-02
# 2    1981-05-31
# 3    1945-02-13
# 4    1939-09-03
# ...         ...
# 1995 1942-04-13
# 1996 1963-05-10
# 1997 1965-07-12
# 1998 1926-08-10
# 1999 1948-11-22
#
# [2000 rows x 1 columns]

# %%
df[df.isnull()]
# Out:
#        id gender dob  zipcode employment_status education marital_status  \
# 0     NaN    NaN NaT      NaN               NaN       NaN            NaN
# 1     NaN    NaN NaT      NaN               NaN       NaN            NaN
# 2     NaN    NaN NaT      NaN               NaN       NaN            NaN
# 3     NaN    NaN NaT      NaN               NaN       NaN            NaN
# 4     NaN    NaN NaT      NaN               NaN       NaN            NaN
# ...   ...    ...  ..      ...               ...       ...            ...
# 1995  NaN    NaN NaT      NaN               NaN       NaN            NaN
# 1996  NaN    NaN NaT      NaN               NaN       NaN            NaN
# 1997  NaN    NaN NaT      NaN               NaN       NaN            NaN
# 1998  NaN    NaN NaT      NaN               NaN       NaN            NaN
# 1999  NaN    NaN NaT      NaN               NaN       NaN            NaN
#
#       children ancestry  avg_commute  daily_internet_use  available_vehicles  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#                      id  gender        dob  zipcode employment_status  \
# 0          Amelia Nixon  female 1944-03-09    89136           retired
# 1           Clara Hicks  female 1966-07-02    94105          employed
# 2           Mason Brown    male 1981-05-31    89127          employed
# 3          Michael Rice    male 1945-02-13    44101           retired
# 4        Eleanor Ritter  female 1939-09-03    89136           retired
# ...                 ...     ...        ...      ...               ...
# 1995      Ethan Johnson    male 1942-04-13    89127           retired
# 1996  Natalia Dominguez  female 1963-05-10    60612        unemployed
# 1997      Joseph Zuniga    male 1965-07-12    94110          employed
# 1998      Daniel Murphy    male 1926-08-10    90015           retired
# 1999      Samuel Harris    male 1948-11-22    43210           retired
#
#        education marital_status  children     ancestry  avg_commute  \
# ...

# %%
df.isnull().any()
# Out:
# id                    False
# gender                False
# dob                   False
# zipcode               False
# employment_status     False
# education             False
# marital_status        False
# children              False
# ancestry              False
# avg_commute           False
# daily_internet_use    False
# available_vehicles    False
# military_service      False
# disease               False
# dtype: bool

# %%
df
# Out:
#                      id  gender        dob  zipcode employment_status  \
# 0          Amelia Nixon  female 1944-03-09    89136           retired
# 1           Clara Hicks  female 1966-07-02    94105          employed
# 2           Mason Brown    male 1981-05-31    89127          employed
# 3          Michael Rice    male 1945-02-13    44101           retired
# 4        Eleanor Ritter  female 1939-09-03    89136           retired
# ...                 ...     ...        ...      ...               ...
# 1995      Ethan Johnson    male 1942-04-13    89127           retired
# 1996  Natalia Dominguez  female 1963-05-10    60612        unemployed
# 1997      Joseph Zuniga    male 1965-07-12    94110          employed
# 1998      Daniel Murphy    male 1926-08-10    90015           retired
# 1999      Samuel Harris    male 1948-11-22    43210           retired
#
#        education marital_status  children     ancestry  avg_commute  \
# ...

# %%
df = df.rename(columns={'': 'ID', 'id': 'name'})

# %%
df
# Out:
#                    name  gender        dob  zipcode employment_status  \
# 0          Amelia Nixon  female 1944-03-09    89136           retired
# 1           Clara Hicks  female 1966-07-02    94105          employed
# 2           Mason Brown    male 1981-05-31    89127          employed
# 3          Michael Rice    male 1945-02-13    44101           retired
# 4        Eleanor Ritter  female 1939-09-03    89136           retired
# ...                 ...     ...        ...      ...               ...
# 1995      Ethan Johnson    male 1942-04-13    89127           retired
# 1996  Natalia Dominguez  female 1963-05-10    60612        unemployed
# 1997      Joseph Zuniga    male 1965-07-12    94110          employed
# 1998      Daniel Murphy    male 1926-08-10    90015           retired
# 1999      Samuel Harris    male 1948-11-22    43210           retired
#
#        education marital_status  children     ancestry  avg_commute  \
# ...

# %%
df.convert_dtypes().dtypes
# Out:
# name                          string
# gender                      category
# dob                   datetime64[ns]
# zipcode                        Int64
# employment_status           category
# education                     string
# marital_status              category
# children                       Int64
# ancestry                      string
# avg_commute                  float64
# daily_internet_use           float64
# available_vehicles             Int64
# military_service            category
# disease                       string
# dtype: object

# %%
df.describe()
# Out:
#             zipcode     children  avg_commute  daily_internet_use  \
# count   2000.000000  2000.000000  2000.000000         2000.000000
# mean   63387.827500     2.266500    30.376895            4.993325
# std    30165.490876     1.615792    10.026961            1.387846
# min    10001.000000     0.000000    -2.470000            1.010000
# 25%    43221.000000     1.000000    23.460000            4.020000
# 50%    60612.000000     2.000000    30.320000            5.010000
# 75%    90008.000000     3.000000    37.127500            5.972500
# max    94110.000000     7.000000    63.730000            8.820000
#
#        available_vehicles
# count         2000.000000
# mean             1.746000
# std              1.118977
# min              0.000000
# 25%              1.000000
# 50%              2.000000
# 75%              3.000000
# max              4.000000

# %%
df[(df['children'] > 1) & (df['available_vehicles'] == 2)]
# Out:
#                  name  gender        dob  zipcode employment_status  \
# 1         Clara Hicks  female 1966-07-02    94105          employed
# 11        Bella Small  female 1959-03-30    10026           retired
# 13    Samantha Flores  female 1972-12-15    94105          employed
# 14        Riley Jones  female 1967-11-20    94105          employed
# 15        Jake Glover    male 1943-12-27    60605           retired
# ...               ...     ...        ...      ...               ...
# 1965  Makenzie Murray  female 1966-10-23    90015          employed
# 1967     Madison Bell  female 1945-10-27    90008           retired
# 1982       Lily Jones  female 1935-02-05    60605           retired
# 1987   Asher Thompson    male 1941-01-04    89127           retired
# 1997    Joseph Zuniga    male 1965-07-12    94110          employed
#
#        education marital_status  children     ancestry  avg_commute  \
# 1         phd/md        married         4       Sweden        15.16
# ...
