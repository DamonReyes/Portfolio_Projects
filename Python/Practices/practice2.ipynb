# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_original = pd.read_csv('hotel_bookings.csv', parse_dates=['reservation_status_date'])

# %%
df_original
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df = df_original.copy(deep=True)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.convert_dtypes().dtypes
# Out:
# hotel                                     string
# is_canceled                                Int64
# lead_time                                  Int64
# arrival_date_year                          Int64
# arrival_date_month                        string
# arrival_date_week_number                   Int64
# arrival_date_day_of_month                  Int64
# stays_in_weekend_nights                    Int64
# stays_in_week_nights                       Int64
# adults                                     Int64
# children                                   Int64
# babies                                     Int64
# meal                                      string
# country                                   string
# market_segment                            string
# distribution_channel                      string
# is_repeated_guest                          Int64
# previous_cancellations                     Int64
# previous_bookings_not_canceled             Int64
# ...

# %%
df[['arrival_date_year']] = pd.to_datetime(df['arrival_date_year'],
                                          errors = 'coerce', format = '%Y')

# %%
df[['arrival_date_month']] = pd.to_datetime(df['arrival_date_month'],
                                          errors = 'coerce', format = '%B')

# %%
df[['arrival_date_week_number']] = pd.to_datetime(df['arrival_date_week_number'],
                                          errors = 'coerce', format = '%W')

# %%
df[['arrival_date_day_of_month']] = pd.to_datetime(df['arrival_date_day_of_month'],
                                          errors = 'coerce', format = '%d')

# %%
df.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                 datetime64[ns]
# arrival_date_month                datetime64[ns]
# arrival_date_week_number          datetime64[ns]
# arrival_date_day_of_month         datetime64[ns]
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  stays_in_weekend_nights  \
# count  119390.000000  119390.000000            119390.000000
# mean        0.370416     104.011416                 0.927599
# std         0.482918     106.863097                 0.998613
# min         0.000000       0.000000                 0.000000
# 25%         0.000000      18.000000                 0.000000
# 50%         0.000000      69.000000                 1.000000
# 75%         1.000000     160.000000                 2.000000
# max         1.000000     737.000000                19.000000
#
#        stays_in_week_nights         adults       children         babies  \
# count         119390.000000  119390.000000  119386.000000  119390.000000
# mean               2.500302       1.856403       0.103890       0.007949
# std                1.908286       0.579261       0.398561       0.097436
# min                0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number             0
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
#        arrival_date_month arrival_date_week_number arrival_date_day_of_month  \
# 0              1900-07-01                      NaT                1900-01-01
# ...

# %%
df[['hotel','reservation_status','is_repeated_guest']] = df[['hotel','reservation_status','is_repeated_guest']].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  category
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  datetime64[ns]
#  4   arrival_date_month              119390 non-null  datetime64[ns]
#  5   arrival_date_week_number        0 non-null       datetime64[ns]
#  6   arrival_date_day_of_month       119390 non-null  datetime64[ns]
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
# ...

# %%
df.drop_duplicates()
# Out:
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
#        arrival_date_month arrival_date_week_number arrival_date_day_of_month  \
# 0                     NaT                      NaT                1900-01-01
# ...

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.drop(['company'], axis=1, inplace=True)

# %%
df.fillna(df.median())
# Out:
# <ipython-input-37-dac89757a4d4>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.median())
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
# ...

# %%
df.drop_duplicates()
# Out:
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
#        arrival_date_month arrival_date_week_number arrival_date_day_of_month  \
# 0                     NaT                      NaT                1900-01-01
# ...

# %%
df.fillna(df.median())
# Out:
# <ipython-input-39-dac89757a4d4>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.median())
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
# ...

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
#        arrival_date_month arrival_date_week_number arrival_date_day_of_month  \
# 0              1900-07-01                      NaT                1900-01-01
# ...

# %%
df['arrival_date_month'] = df['reservation_status_date'].dt.month
df['arrival_date_day_of_month'] = df['reservation_status_date'].dt.day
df
# Out:
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
#         arrival_date_month  arrival_date_day_of_month  \
# 0                        7                          1
# 1                        7                          1
# ...

# %%
df.drop(['arrival_date_week_number'], axis=1, inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
#         arrival_date_month  arrival_date_day_of_month  \
# 0                        7                          1
# 1                        7                          1
# ...

# %%
df['agent'].fillna(0)
# Out:
# 0           0.0
# 1           0.0
# 2           0.0
# 3         304.0
# 4         240.0
#           ...
# 119385    394.0
# 119386      9.0
# 119387      9.0
# 119388     89.0
# 119389      9.0
# Name: agent, Length: 119390, dtype: float64

# %%
df.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_month  \
# count  119390.000000  119390.000000       119390.000000
# mean        0.370416     104.011416            6.334123
# std         0.482918     106.863097            3.346352
# min         0.000000       0.000000            1.000000
# 25%         0.000000      18.000000            3.000000
# 50%         0.000000      69.000000            6.000000
# 75%         1.000000     160.000000            9.000000
# max         1.000000     737.000000           12.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count              119390.000000            119390.000000
# mean                   15.666639                 0.927599
# std                     8.778432                 0.998613
# min                     1.000000                 0.000000
# 25%                     8.000000                 0.000000
# 50%                    16.000000                 1.000000
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time arrival_date_year  \
# 0       Resort Hotel            0        342        2015-01-01
# 1       Resort Hotel            0        737        2015-01-01
# 2       Resort Hotel            0          7        2015-01-01
# 3       Resort Hotel            0         13        2015-01-01
# 4       Resort Hotel            0         14        2015-01-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-01-01
# 119386    City Hotel            0        102        2017-01-01
# 119387    City Hotel            0         34        2017-01-01
# 119388    City Hotel            0        109        2017-01-01
# 119389    City Hotel            0        205        2017-01-01
#
#         arrival_date_month  arrival_date_day_of_month  \
# 0                        7                          1
# 1                        7                          1
# ...

# %% [markdown]
# ya termine la transformacionde de datos, sigue el analisis

# %%
df['hotel'].value_counts() #tiene mas datos el City hotel
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
df.describe(include='all')
# Out:
# <ipython-input-103-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
# <ipython-input-103-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#              hotel    is_canceled      lead_time    arrival_date_year  \
# count       119390  119390.000000  119390.000000               119390
# unique           2            NaN            NaN                    3
# top     City Hotel            NaN            NaN  2016-01-01 00:00:00
# freq         79330            NaN            NaN                56707
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  category
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  datetime64[ns]
#  4   arrival_date_month              119390 non-null  int64
#  5   arrival_date_day_of_month       119390 non-null  int64
#  6   stays_in_weekend_nights         119390 non-null  int64
#  7   stays_in_week_nights            119390 non-null  int64
#  8   adults                          119390 non-null  int64
#  9   children                        119386 non-null  float64
#  10  babies                          119390 non-null  int64
#  11  meal                            119390 non-null  object
# ...

# %%
df.groupby('reservation_status').std()
# Out:
#                     is_canceled   lead_time  arrival_date_month  \
# reservation_status
# Canceled                    0.0  118.829882            3.631698
# Check-Out                   0.0   91.109888            3.156782
# No-Show                     0.0   66.627177            3.425511
#
#                     arrival_date_day_of_month  stays_in_weekend_nights  \
# reservation_status
# Canceled                             8.713736                 1.000210
# Check-Out                            8.798740                 0.993371
# No-Show                              9.130390                 1.227127
#
#                     stays_in_week_nights    adults  children    babies  \
# reservation_status
# Canceled                        1.849113  0.679961  0.408687  0.061820
# Check-Out                       1.924803  0.510451  0.390836  0.113007
# No-Show                         2.721770  0.555210  0.497138  0.081176
#
# ...
