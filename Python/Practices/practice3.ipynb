# %%
import pandas as pd
import numpy as np

# %%
df_original = pd.read_csv('AB_NYC_2019.csv', parse_dates=['last_review'])

# %%
df = df_original.copy(deep=True)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df.convert_dtypes().dtypes
# Out:
# id                                         Int64
# name                                      string
# host_id                                    Int64
# host_name                                 string
# neighbourhood_group                       string
# neighbourhood                             string
# latitude                                 float64
# longitude                                float64
# room_type                                 string
# price                                      Int64
# minimum_nights                             Int64
# number_of_reviews                          Int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             Int64
# availability_365                           Int64
# dtype: object

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
df.drop(['host_id', 'latitude', 'longitude', 'availability_365'], axis=1, inplace=True)

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df.describe(include='all')
# Out:
# <ipython-input-112-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#                   name host_name neighbourhood_group neighbourhood  \
# count            48879     48874               48895         48895
# unique           47905     11452                   5           221
# top     Hillside Hotel   Michael           Manhattan  Williamsburg
# freq                18       417               21661          3920
# first              NaN       NaN                 NaN           NaN
# last               NaN       NaN                 NaN           NaN
# mean               NaN       NaN                 NaN           NaN
# std                NaN       NaN                 NaN           NaN
# ...

# %%
df[['room_type']] = df[['room_type']].astype('category')

# %%
df.duplicated() #no hay duplicados
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %%
df
# Out:
#                                                     name      host_name  \
# 0                     Clean & quiet apt home by the park           John
# 1                                  Skylit Midtown Castle       Jennifer
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      Elisabeth
# 3                        Cozy Entire Floor of Brownstone    LisaRoxanne
# 4       Entire Apt: Spacious Studio/Loft by central park          Laura
# ...                                                  ...            ...
# 48890    Charming one bedroom - newly renovated rowhouse        Sabrina
# 48891      Affordable room in Bushwick/East Williamsburg        Marisol
# 48892            Sunny Studio at Historical Neighborhood  Ilgar & Aysel
# 48893               43rd St. Time Square-cozy single bed            Taz
# 48894  Trendy duplex in the very heart of Hell's Kitchen     Christophe
#
#       neighbourhood_group       neighbourhood        room_type  price  \
# ...

# %%
df.isnull()
# Out:
#         name  host_name  neighbourhood_group  neighbourhood  room_type  price  \
# 0      False      False                False          False      False  False
# 1      False      False                False          False      False  False
# 2      False      False                False          False      False  False
# 3      False      False                False          False      False  False
# 4      False      False                False          False      False  False
# ...      ...        ...                  ...            ...        ...    ...
# 48890  False      False                False          False      False  False
# 48891  False      False                False          False      False  False
# 48892  False      False                False          False      False  False
# 48893  False      False                False          False      False  False
# 48894  False      False                False          False      False  False
#
# ...

# %%
df[['reviews_per_month']] = df[['reviews_per_month']].fillna(df.median())
# Out:
# <ipython-input-117-721746e49cc8>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df[['reviews_per_month']] = df[['reviews_per_month']].fillna(df.median())

# %%
#df = pd.concat([df[['reviews_per_month']], df[['reviews_per_month']].interpolate()],axis=1)

# %%
df.describe(include='all')
# Out:
# <ipython-input-119-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#                   name host_name neighbourhood_group neighbourhood  \
# count            48879     48874               48895         48895
# unique           47905     11452                   5           221
# top     Hillside Hotel   Michael           Manhattan  Williamsburg
# freq                18       417               21661          3920
# first              NaN       NaN                 NaN           NaN
# last               NaN       NaN                 NaN           NaN
# mean               NaN       NaN                 NaN           NaN
# std                NaN       NaN                 NaN           NaN
# ...

# %%
df.groupby('room_type').describe()
# Out:
#                      price                                                \
#                      count    mean     std   min     25%     50%     75%
# room_type
# Entire home/apt 25,409.000 211.794 284.042 0.000 120.000 160.000 229.000
# Private room    22,326.000  89.781 160.205 0.000  50.000  70.000  95.000
# Shared room      1,160.000  70.128 101.725 0.000  33.000  45.000  75.000
#
#                            minimum_nights        ... reviews_per_month         \
#                        max          count  mean  ...               75%    max
# room_type                                        ...
# Entire home/apt 10,000.000     25,409.000 8.507  ...             1.520 15.780
# Private room    10,000.000     22,326.000 5.378  ...             1.650 58.500
# Shared room      1,800.000      1,160.000 6.475  ...             1.600 10.770
#
#                 calculated_host_listings_count                            \
# ...

# %%
df.groupby('neighbourhood_group').describe()
#aca tambien nos interesaria ver el maximo(max) el minimo(min) la media(median) y operaciones matematicas imteresantes
# Out:
#                          price                                                \
#                          count    mean     std    min    25%     50%     75%
# neighbourhood_group
# Bronx                1,091.000  87.497 106.709  0.000 45.000  65.000  99.000
# Brooklyn            20,104.000 124.383 186.874  0.000 60.000  90.000 150.000
# Manhattan           21,661.000 196.876 291.383  0.000 95.000 150.000 220.000
# Queens               5,666.000  99.518 167.102 10.000 50.000  75.000 110.000
# Staten Island          373.000 114.812 277.620 13.000 50.000  75.000 110.000
#
#                                minimum_nights        ... reviews_per_month  \
#                            max          count  mean  ...               75%
# neighbourhood_group                                  ...
# Bronx                2,500.000      1,091.000 4.561  ...             2.360
# Brooklyn            10,000.000     20,104.000 6.057  ...             1.550
# ...

# %%
df[['minimum_nights', 'number_of_reviews', 'price', 'calculated_host_listings_count']].max()
# Out:
# minimum_nights                     1250
# number_of_reviews                   629
# price                             10000
# calculated_host_listings_count      327
# dtype: int64

# %%
df.groupby('room_type')[['neighbourhood_group']].describe() #podemos agregar multiples funciones estadisticas ya agrupadas
# Out:
#                 neighbourhood_group
#                               count unique        top   freq
# room_type
# Entire home/apt               25409      5  Manhattan  13199
# Private room                  22326      5   Brooklyn  10132
# Shared room                    1160      5  Manhattan    480

# %%
df.groupby('neighbourhood_group')[['reviews_per_month']].describe()
# Out:
#                     reviews_per_month                                      \
#                                 count  mean   std   min   25%   50%   75%
# neighbourhood_group
# Bronx                       1,091.000 1.618 1.564 0.020 0.680 0.870 2.360
# Brooklyn                   20,104.000 1.181 1.389 0.010 0.250 0.720 1.550
# Manhattan                  21,661.000 1.144 1.446 0.010 0.250 0.720 1.300
# Queens                      5,666.000 1.706 2.046 0.010 0.500 0.760 2.308
# Staten Island                 373.000 1.690 1.602 0.020 0.720 1.000 2.310
#
#
#                        max
# neighbourhood_group
# Bronx               10.340
# Brooklyn            14.000
# Manhattan           58.500
# Queens              20.940
# Staten Island       10.120

# %%
df
# Out:
#                                                     name      host_name  \
# 0                     Clean & quiet apt home by the park           John
# 1                                  Skylit Midtown Castle       Jennifer
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      Elisabeth
# 3                        Cozy Entire Floor of Brownstone    LisaRoxanne
# 4       Entire Apt: Spacious Studio/Loft by central park          Laura
# ...                                                  ...            ...
# 48890    Charming one bedroom - newly renovated rowhouse        Sabrina
# 48891      Affordable room in Bushwick/East Williamsburg        Marisol
# 48892            Sunny Studio at Historical Neighborhood  Ilgar & Aysel
# 48893               43rd St. Time Square-cozy single bed            Taz
# 48894  Trendy duplex in the very heart of Hell's Kitchen     Christophe
#
#       neighbourhood_group       neighbourhood        room_type  price  \
# ...
